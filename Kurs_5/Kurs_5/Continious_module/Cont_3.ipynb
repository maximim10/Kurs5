# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def get_3_approx_nonhomog(C_and_N_functions, P_functions, C_type, Plot_flag = 1):
    C_ijkl = C_and_N_functions[0]
    N_b_kpq0 = C_and_N_functions[1][0]
    N_e_kpq0 = C_and_N_functions[1][1]
    N_b_kpq0q1 = C_and_N_functions[2][0]
    N_e_kpq0q1 = C_and_N_functions[2][1]
    P_ijpq0 = P_functions[1][0]
    Q_ijpq0 = P_functions[1][1]
    P_ijpq0q1 = P_functions[2][0]
    Q_ijpq0q1 = P_functions[2][1]
    x = sympy.Symbol("x")
    C1 = Symbol("C1")
    C2 = Symbol("C2")
    undef_func = sympy.Function("undef_func")
    N_b_kpq0q1q2 = [[[[[None, None, None] for i4 in range(3)] for i3 in range(3)] for i2 in range(3)] for i1 in range(3)]
    N_e_kpq0q1q2 = [[[[[None, None, None] for i4 in range(3)] for i3 in range(3)] for i2 in range(3)] for i1 in range(3)]
    Q_ijpq0q1q2 = [[[[[[None, None, None] for i5 in range(3)] for i4 in range(3)] for i3 in range(3)] for i2 in range(3)] for i1 in range(3)]
    P_ijpq0q1q2 = [[[[[[None, None, None] for i5 in range(3)] for i4 in range(3)] for i3 in range(3)] for i2 in range(3)] for i1 in range(3)]
#     for i in range(3):
#         for p in range(2):      
#             for q0 in range(2):
#                 for q1 in range(2):
#                     for q2 in range(2):
#                         b = sympy.integrate(P_ijpq0q1[i][q2][p][q0][q1], (x, -1/2, 1/2))
#                         b1 = sympy.integrate(P_ijpq0[p][q0][q1][q2]*x if i == 2 else 0, (x, -1/2, 1/2))
#                         b2 = sympy.integrate(P_ijpq0q1[i][q2][p][q0][q1] + P_ijpq0[p][q0][q1][q2]*x, (x, -1/2, 1/2))
#                         print(b, b1, b2)
    for i in range(3):
        for p in range(2):      
            for q0 in range(2):
                for q1 in range(2):
                    for q2 in range(2):
                        
                        b = sympy.integrate(-Q_ijpq0q1[i][q2][p][q0][q1] + Q_ijpq0q1[i][q2][p][q0][q1], (x, -1/2, 1/2))
#                         b1 = sympy.integrate(P_ijpq0q1[i][q2][p][q0][q1], (x, -1/2, 1/2))
                        print(f"b_{i+1}{3}{p+1}{q0+1}{q1+1}{q2+1} = ", b)
                        eq_for_2_integrations = -b +\
                                              + C_ijkl[i][q2][0][q1]*N_b_kpq0[0][p][q0] +\
                                              + C_ijkl[i][q2][1][q1]*N_b_kpq0[1][p][q0] +\
                                              + C_ijkl[i][q2][2][q1]*N_b_kpq0[2][p][q0] +\
                                              + (C_ijkl[i][q2][0][2] + C_ijkl[i][2][0][q2])*N_b_kpq0q1[0][p][q0][q1].diff(x) +\
                                              + (C_ijkl[i][q2][1][2] + C_ijkl[i][2][1][q2])*N_b_kpq0q1[1][p][q0][q1].diff(x) +\
                                              + (C_ijkl[i][q2][2][2] + C_ijkl[i][2][2][q2])*N_b_kpq0q1[2][p][q0][q1].diff(x)
                        eq_for_2_integrations /= -C_ijkl[i][2][i][2]
                        eq_for_2_integrations = eq_for_2_integrations.simplify()
                        #print(f"{C_ijkl[i][q2][1][q1] = }; {N_b_kpq0[0][p][q0] = }; {N_b_kpq0q1[2][p][q0][q1].diff(x) = }")
                        
                        if eq_for_2_integrations.func == (x*3).func and C_type ==  "FGM":
                            eq_for_2_integrations = poly_log_decomp(eq_for_2_integrations)
                            
                            eq_for_2_integrations = (eq_for_2_integrations.expand())
                            print(f"{eq_for_2_integrations = }")
                            one_param_solution = 0
                            for summand in eq_for_2_integrations.args:
                                print(summand, summand.func)
                                zero_summand = 0
                                if summand.func == (x*2).func:
                                    for mult in summand.args:
                                        if mult.func == (x-x+1).func and mult < 1e-4:
                                            zero_summand = 1
                                if zero_summand:
                                    continue
                                one_param_solution += sympy.integrate(summand, (x))
                            print(f"{one_param_solution = }")
                            two_param_solution = 0
                            for summand in one_param_solution.args:
                                two_param_solution += sympy.integrate(summand, x)
                            #print(f"{two_param_solution = }")
                            c1 = 0
                            two_param_solution = correct_logarithms(two_param_solution)
                            for summand in two_param_solution.args:
                                c1 -= sympy.integrate(summand, (x, -1/2, 1/2))
                        else:
                            one_param_solution = sympy.integrate(eq_for_2_integrations, x) 
                            two_param_solution = sympy.integrate(one_param_solution, x)
                            c1 = -integrate(two_param_solution, (x, -1/2, 1/2))
                        #print(f"{one_param_solution = }")
                        #print(f"{two_param_solution = }")
                        bound_cond = C_ijkl[i][2][0][q2]*N_b_kpq0q1[0][p][q0][q1] +\
                                    + C_ijkl[i][2][1][q2]*N_b_kpq0q1[1][p][q0][q1] +\
                                    + C_ijkl[i][2][2][q2]*N_b_kpq0q1[2][p][q0][q1] +\
                                    + C_ijkl[i][2][i][2]*(one_param_solution+C2)
                        #print(f"{bound_cond = }")
                        bound_cond = sympy.Eq(bound_cond.subs(x, -1/2), 0)
                        c2 = solve(bound_cond, C2)[0]

                        bound_cond1 = C_ijkl[i][2][0][q2]*N_b_kpq0q1[0][p][q0][q1] +\
                                    + C_ijkl[i][2][1][q2]*N_b_kpq0q1[1][p][q0][q1] +\
                                    + C_ijkl[i][2][2][q2]*N_b_kpq0q1[2][p][q0][q1] +\
                                    + C_ijkl[i][2][i][2]*(one_param_solution+C2)
                        #print(f"sum = {C_ijkl[i][2][0][q1]*N_b_kpq0[0][p][q0] + C_ijkl[i][2][1][q1]*N_b_kpq0[1][p][q0] + C_ijkl[i][2][2][q1]*N_b_kpq0[2][p][q0]}")
                        bound_cond1 = sympy.Eq(bound_cond1.subs(x, 1/2), 0)
                        c2_1 = solve(bound_cond1, C2)[0]
                        #print(f"{c2 = }; {c2_1 = }\n")
                        final_solution = two_param_solution + c2*x + c1
                        final_solution1 = two_param_solution + c2_1*x + c1
                        N_b_kpq0q1q2[i][p][q0][q1][q2] = final_solution
#                         print(f"N_b_{i+1}{p+1}{q0+1}{q1+1}{q2+1} = {N_b_kpq0q1q2[i][p][q0][q1][q2]}")
                        if C_type != "Symbolic" and Plot_flag:
                            Plot_function([N_b_kpq0q1q2[i][p][q0][q1][q2]], f"N_b_{i+1}{p+1}{q0+1}{q1+1}{q2+1}")
    for i in range(3):
        for p in range(2):      
            for q0 in range(2):
                for q1 in range(2):
                    for q2 in range(2):
                        a = sympy.integrate(P_ijpq0q1[i][q2][p][q0][q1], (x, -1/2, 1/2))
                        print(f"a_{i}{3}{p}{q0}{q1}{q2} = ", a)
                        eq_for_2_integrations = -a +\
                                              + C_ijkl[i][q2][0][q1]*N_e_kpq0[0][p][q0] +\
                                              + C_ijkl[i][q2][1][q1]*N_e_kpq0[1][p][q0] +\
                                              + C_ijkl[i][q2][2][q1]*N_e_kpq0[2][p][q0] +\
                                              + (C_ijkl[i][q2][0][2] + C_ijkl[i][2][0][q2])*N_e_kpq0q1[0][p][q0][q1].diff(x) +\
                                              + (C_ijkl[i][q2][1][2] + C_ijkl[i][2][1][q2])*N_e_kpq0q1[1][p][q0][q1].diff(x) +\
                                              + (C_ijkl[i][q2][2][2] + C_ijkl[i][2][2][q2])*N_e_kpq0q1[2][p][q0][q1].diff(x)
                        eq_for_2_integrations /= -C_ijkl[i][2][i][2]
                        eq_for_2_integrations = eq_for_2_integrations.simplify()                        
                        one_param_solution = sympy.integrate(eq_for_2_integrations, x) 
                        two_param_solution = sympy.integrate(one_param_solution, x)
                        c1 = -integrate(two_param_solution, (x, -1/2, 1/2))
                        bound_cond = C_ijkl[i][2][0][q2]*N_e_kpq0q1[0][p][q0][q1] +\
                                    + C_ijkl[i][2][1][q2]*N_e_kpq0q1[1][p][q0][q1] +\
                                    + C_ijkl[i][2][2][q2]*N_e_kpq0q1[2][p][q0][q1] +\
                                    + C_ijkl[i][2][i][2]*(one_param_solution+C2)
                        bound_cond = sympy.Eq(bound_cond.subs(x, -1/2), 0)
                        c2 = solve(bound_cond, C2)[0]

                        final_solution = two_param_solution + c2*x + c1
                        N_e_kpq0q1q2[i][p][q0][q1][q2] = final_solution
#                         print(f"N_e_{i+1}{p+1}{q0+1}{q1+1}{q2+1} = {N_e_kpq0q1q2[i][p][q0][q1][q2]}")
                        if C_type != "Symbolic" and Plot_flag:
                            Plot_function([N_e_kpq0q1q2[i][p][q0][q1][q2]], f"N_e_{i+1}{p+1}{q0+1}{q1+1}{q2+1}")
    for i in range(3):
        for j in range(3):
            for p in range(2):
                for q0 in range(2):
                    for q1 in range(2):
                        for q2 in range(2):
                            Q_ijpq0q1q2[i][j][p][q0][q1][q2] = C_ijkl[i][j][0][q2]*N_b_kpq0q1[0][p][q0][q1] + C_ijkl[i][j][1][q2]*N_b_kpq0q1[1][p][q0][q1] + C_ijkl[i][j][2][q2]*N_b_kpq0q1[2][p][q0][q1] +\
                                                             + C_ijkl[i][j][0][2]*N_b_kpq0q1q2[0][p][q0][q1][q2].diff(x) + C_ijkl[i][j][1][2]*N_b_kpq0q1q2[1][p][q0][q1][q2].diff(x) + C_ijkl[i][j][2][2]*N_b_kpq0q1q2[2][p][q0][q1][q2].diff(x)                
                            P_ijpq0q1q2[i][j][p][q0][q1][q2] = C_ijkl[i][j][0][q2]*N_e_kpq0q1[0][p][q0][q1] + C_ijkl[i][j][1][q2]*N_e_kpq0q1[1][p][q0][q1] + C_ijkl[i][j][2][q2]*N_e_kpq0q1[2][p][q0][q1] +\
                                                             + C_ijkl[i][j][0][2]*N_e_kpq0q1q2[0][p][q0][q1][q2].diff(x) + C_ijkl[i][j][1][2]*N_e_kpq0q1q2[1][p][q0][q1][q2].diff(x) + C_ijkl[i][j][2][2]*N_e_kpq0q1q2[2][p][q0][q1][q2].diff(x)                
                            if C_type != "Symbolic" and Plot_flag:
                                Plot_function([P_ijpq0q1q2[i][j][p][q0][q1][q2]], f"P_{i+1}{j+1}{p+1}{q0+1}{q1+1}{q2+1}")
                                Plot_function([Q_ijpq0q1q2[i][j][p][q0][q1][q2]], f"Q_{i+1}{j+1}{p+1}{q0+1}{q1+1}{q2+1}")
    return N_b_kpq0q1q2, P_ijpq0q1q2, N_e_kpq0q1q2, Q_ijpq0q1q2
